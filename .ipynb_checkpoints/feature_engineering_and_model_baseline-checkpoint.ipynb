# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_analysis = pd.read_csv('data/df_analysis.csv', index_col='Time')

# %%
df_analysis['Precipitation_7d_rolling_sum'].replace(np.nan, 0, inplace =True)
# Out:
# C:\Users\ALiEN\AppData\Local\Temp\ipykernel_8468\1070904917.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analysis['Precipitation_7d_rolling_sum'].replace(np.nan, 0, inplace =True)

# %%
df_analysis.head()
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-01-01               0.0         0.3        20.2
# 1999-01-02               0.0         0.8        21.0
# 1999-01-03               0.0         0.5        23.6
# 1999-01-04               0.0         1.2        22.2
# 1999-01-05               0.0         1.0        21.7
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-01-01                           0.0  1999      1            1
# 1999-01-02                           0.0  1999      1            2
# 1999-01-03                           0.0  1999      1            3
# 1999-01-04                           0.0  1999      1            4
# 1999-01-05                           0.0  1999      1            5
#
#             Day_of_Week  Month_sin  Month_cos  Day_of_Year_sin  \
# Time
# 1999-01-01            4        0.5   0.866025         0.017202
# 1999-01-02            5        0.5   0.866025         0.034398
# 1999-01-03            6        0.5   0.866025         0.051584
# 1999-01-04            0        0.5   0.866025         0.068755
# 1999-01-05            1        0.5   0.866025         0.085906
#
#             Day_of_Year_cos
# Time
# 1999-01-01         0.999852
# 1999-01-02         0.999408
# 1999-01-03         0.998669
# 1999-01-04         0.997634
# 1999-01-05         0.996303

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9422 entries, 1999-01-01 to 2024-10-17
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Precipitation_mm              9422 non-null   float64
#  1   Min_Temp_C                    9422 non-null   float64
#  2   Max_Temp_C                    9422 non-null   float64
#  3   Precipitation_7d_rolling_sum  9422 non-null   float64
#  4   Year                          9422 non-null   int64
#  5   Month                         9422 non-null   int64
#  6   Day_of_Year                   9422 non-null   int64
#  7   Day_of_Week                   9422 non-null   int64
#  8   Month_sin                     9422 non-null   float64
#  9   Month_cos                     9422 non-null   float64
#  10  Day_of_Year_sin               9422 non-null   float64
#  11  Day_of_Year_cos               9422 non-null   float64
# dtypes: float64(8), int64(4)
# memory usage: 956.9+ KB

# %%
df_analysis.isnull().sum()
# Out:
# Precipitation_mm                0
# Min_Temp_C                      0
# Max_Temp_C                      0
# Precipitation_7d_rolling_sum    0
# Year                            0
# Month                           0
# Day_of_Year                     0
# Day_of_Week                     0
# Month_sin                       0
# Month_cos                       0
# Day_of_Year_sin                 0
# Day_of_Year_cos                 0
# dtype: int64

# %%
df_analysis
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-01-01               0.0         0.3        20.2
# 1999-01-02               0.0         0.8        21.0
# 1999-01-03               0.0         0.5        23.6
# 1999-01-04               0.0         1.2        22.2
# 1999-01-05               0.0         1.0        21.7
# ...                      ...         ...         ...
# 2024-10-13               0.0        14.7        28.0
# 2024-10-14               0.0        17.2        27.5
# 2024-10-15               0.0        15.0        27.5
# 2024-10-16               0.0        15.3        27.2
# 2024-10-17               0.0        15.5        27.2
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-01-01                           0.0  1999      1            1
# 1999-01-02                           0.0  1999      1            2
# 1999-01-03                           0.0  1999      1            3
# 1999-01-04                           0.0  1999      1            4
# 1999-01-05                           0.0  1999      1            5
# ...                                  ...   ...    ...          ...
# 2024-10-13                           0.0  2024     10          287
# 2024-10-14                           0.0  2024     10          288
# 2024-10-15                           0.0  2024     10          289
# 2024-10-16                           0.0  2024     10          290
# 2024-10-17                           0.0  2024     10          291
#
#             Day_of_Week  Month_sin  Month_cos  Day_of_Year_sin  \
# Time
# 1999-01-01            4   0.500000   0.866025         0.017202
# 1999-01-02            5   0.500000   0.866025         0.034398
# 1999-01-03            6   0.500000   0.866025         0.051584
# 1999-01-04            0   0.500000   0.866025         0.068755
# 1999-01-05            1   0.500000   0.866025         0.085906
# ...                 ...        ...        ...              ...
# 2024-10-13            6  -0.866025   0.500000        -0.974860
# 2024-10-14            0  -0.866025   0.500000        -0.970882
# 2024-10-15            1  -0.866025   0.500000        -0.966618
# 2024-10-16            2  -0.866025   0.500000        -0.962068
# 2024-10-17            3  -0.866025   0.500000        -0.957232
#
#             Day_of_Year_cos
# Time
# 1999-01-01         0.999852
# 1999-01-02         0.999408
# 1999-01-03         0.998669
# 1999-01-04         0.997634
# 1999-01-05         0.996303
# ...                     ...
# 2024-10-13         0.222820
# 2024-10-14         0.239557
# 2024-10-15         0.256222
# 2024-10-16         0.272811
# 2024-10-17         0.289320
#
# [9422 rows x 12 columns]

# %% [markdown]
# #### Lagged Features (Past Values):
# Crucial for capturing persistence.

# %%
# Lagged temperatures for 1, 2, 3, 7 days prior
for i in [1, 2, 3, 7]:
    df_analysis[f'Max_Temp_C_lag_{i}'] = df_analysis['Max_Temp_C'].shift(i)
    df_analysis[f'Min_Temp_C_lag_{i}'] = df_analysis['Min_Temp_C'].shift(i)

# Lagged precipitation for 1, 2, 3, 7 days prior
for i in [1, 2, 3, 7]:
    df_analysis[f'Precipitation_mm_lag_{i}'] = df_analysis['Precipitation_mm'].shift(i)

# Drop NaNs that result from shifting (these will be at the beginning of the series)
df_analysis.dropna(inplace=True)

# %%
df_analysis
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-01-08               0.0         1.0        20.1
# 1999-01-09               0.0         2.3        14.8
# 1999-01-10               0.0         1.2        17.1
# 1999-01-11               0.0        -2.0        20.4
# 1999-01-12               0.0        -1.4        21.0
# ...                      ...         ...         ...
# 2024-10-13               0.0        14.7        28.0
# 2024-10-14               0.0        17.2        27.5
# 2024-10-15               0.0        15.0        27.5
# 2024-10-16               0.0        15.3        27.2
# 2024-10-17               0.0        15.5        27.2
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-01-08                           0.0  1999      1            8
# 1999-01-09                           0.0  1999      1            9
# 1999-01-10                           0.0  1999      1           10
# 1999-01-11                           0.0  1999      1           11
# 1999-01-12                           0.0  1999      1           12
# ...                                  ...   ...    ...          ...
# 2024-10-13                           0.0  2024     10          287
# 2024-10-14                           0.0  2024     10          288
# 2024-10-15                           0.0  2024     10          289
# 2024-10-16                           0.0  2024     10          290
# 2024-10-17                           0.0  2024     10          291
#
#             Day_of_Week  Month_sin  Month_cos  ...  Max_Temp_C_lag_2  \
# Time                                           ...
# 1999-01-08            4   0.500000   0.866025  ...              21.0
# 1999-01-09            5   0.500000   0.866025  ...              13.6
# 1999-01-10            6   0.500000   0.866025  ...              20.1
# 1999-01-11            0   0.500000   0.866025  ...              14.8
# 1999-01-12            1   0.500000   0.866025  ...              17.1
# ...                 ...        ...        ...  ...               ...
# 2024-10-13            6  -0.866025   0.500000  ...              28.5
# 2024-10-14            0  -0.866025   0.500000  ...              28.3
# 2024-10-15            1  -0.866025   0.500000  ...              28.0
# 2024-10-16            2  -0.866025   0.500000  ...              27.5
# 2024-10-17            3  -0.866025   0.500000  ...              27.5
#
#             Min_Temp_C_lag_2  Max_Temp_C_lag_3  Min_Temp_C_lag_3  \
# Time
# 1999-01-08               0.2              21.7               1.0
# 1999-01-09               0.8              21.0               0.2
# 1999-01-10               1.0              13.6               0.8
# 1999-01-11               2.3              20.1               1.0
# 1999-01-12               1.2              14.8               2.3
# ...                      ...               ...               ...
# 2024-10-13              16.9              29.1              16.5
# 2024-10-14              16.5              28.5              16.9
# 2024-10-15              14.7              28.3              16.5
# 2024-10-16              17.2              28.0              14.7
# 2024-10-17              15.0              27.5              17.2
#
#             Max_Temp_C_lag_7  Min_Temp_C_lag_7  Precipitation_mm_lag_1  \
# Time
# 1999-01-08              20.2               0.3                     0.0
# 1999-01-09              21.0               0.8                     0.0
# 1999-01-10              23.6               0.5                     0.0
# 1999-01-11              22.2               1.2                     0.0
# 1999-01-12              21.7               1.0                     0.0
# ...                      ...               ...                     ...
# 2024-10-13              27.5              18.4                     0.0
# 2024-10-14              29.4              18.5                     0.0
# 2024-10-15              28.5              18.4                     0.0
# 2024-10-16              29.6              16.6                     0.0
# 2024-10-17              29.1              16.5                     0.0
#
#             Precipitation_mm_lag_2  Precipitation_mm_lag_3  \
# Time
# 1999-01-08                     0.0                     0.0
# 1999-01-09                     0.0                     0.0
# 1999-01-10                     0.0                     0.0
# 1999-01-11                     0.0                     0.0
# 1999-01-12                     0.0                     0.0
# ...                            ...                     ...
# 2024-10-13                     0.0                     0.0
# 2024-10-14                     0.0                     0.0
# 2024-10-15                     0.0                     0.0
# 2024-10-16                     0.0                     0.0
# 2024-10-17                     0.0                     0.0
#
#             Precipitation_mm_lag_7
# Time
# 1999-01-08                    0.00
# 1999-01-09                    0.00
# 1999-01-10                    0.00
# 1999-01-11                    0.00
# 1999-01-12                    0.00
# ...                            ...
# 2024-10-13                    0.01
# 2024-10-14                    0.00
# 2024-10-15                    0.00
# 2024-10-16                    0.00
# 2024-10-17                    0.00
#
# [9415 rows x 24 columns]

# %% [markdown]
# ### Rolled window features (aggregates of past values):
# Capture recent trends and variability. Useful for capturing "weather regimes."

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9415 entries, 1999-01-08 to 2024-10-17
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Precipitation_mm              9415 non-null   float64
#  1   Min_Temp_C                    9415 non-null   float64
#  2   Max_Temp_C                    9415 non-null   float64
#  3   Precipitation_7d_rolling_sum  9415 non-null   float64
#  4   Year                          9415 non-null   int64
#  5   Month                         9415 non-null   int64
#  6   Day_of_Year                   9415 non-null   int64
#  7   Day_of_Week                   9415 non-null   int64
#  8   Month_sin                     9415 non-null   float64
#  9   Month_cos                     9415 non-null   float64
#  10  Day_of_Year_sin               9415 non-null   float64
#  11  Day_of_Year_cos               9415 non-null   float64
#  12  Max_Temp_C_lag_1              9415 non-null   float64
#  13  Min_Temp_C_lag_1              9415 non-null   float64
#  14  Max_Temp_C_lag_2              9415 non-null   float64
#  15  Min_Temp_C_lag_2              9415 non-null   float64
#  16  Max_Temp_C_lag_3              9415 non-null   float64
#  17  Min_Temp_C_lag_3              9415 non-null   float64
#  18  Max_Temp_C_lag_7              9415 non-null   float64
#  19  Min_Temp_C_lag_7              9415 non-null   float64
#  20  Precipitation_mm_lag_1        9415 non-null   float64
#  21  Precipitation_mm_lag_2        9415 non-null   float64
#  22  Precipitation_mm_lag_3        9415 non-null   float64
#  23  Precipitation_mm_lag_7        9415 non-null   float64
# dtypes: float64(20), int64(4)
# memory usage: 1.8+ MB

# %%
# Rolling mean and std dev for temperatures over 7 and 30 days
for window in [7, 30]:
    df_analysis[f'Max_Temp_C_rolling_mean_{window}d'] = df_analysis['Max_Temp_C'].rolling(window=window).mean()
    df_analysis[f'Min_Temp_C_rolling_mean_{window}d'] = df_analysis['Min_Temp_C'].rolling(window=window).mean()
    df_analysis[f'Max_Temp_C_rolling_std_{window}d'] = df_analysis['Max_Temp_C'].rolling(window=window).std()
    df_analysis[f'Min_Temp_C_rolling_std_{window}d'] = df_analysis['Min_Temp_C'].rolling(window=window).std()

# Rolling sum for precipitation over 7 and 30 days
for window in [7, 30]:
    df_analysis[f'Precipitation_mm_rolling_sum_{window}d'] = df_analysis['Precipitation_mm'].rolling(window=window).sum()
    df_analysis[f'Precipitation_mm_rolling_std_{window}d'] = df_analysis['Precipitation_mm'].rolling(window=window).std()

# Drop NaNs created by rolling windows (these will be at the very beginning)
df_analysis.dropna(inplace=True)

# %%
# Derived Features (Interactions/Transformations):
df_analysis['Daily_Temp_Range'] = df_analysis['Max_Temp_C'] - df_analysis['Min_Temp_C']
# You could also add lagged versions of this
df_analysis['Daily_Temp_Range_lag_1'] = df_analysis['Daily_Temp_Range'].shift(1)

# If you anticipate non-linear effects, polynomial features (Max_Temp_C_squared, etc.) could be added, but let's hold off unless needed.

# %%
df_analysis
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-03-07               0.0         9.5        29.0
# 1999-03-08               0.0        10.3        31.0
# 1999-03-09               0.0         8.7        31.1
# 1999-03-10               0.0         8.2        31.0
# 1999-03-11               0.0         7.1        29.5
# ...                      ...         ...         ...
# 2024-10-13               0.0        14.7        28.0
# 2024-10-14               0.0        17.2        27.5
# 2024-10-15               0.0        15.0        27.5
# 2024-10-16               0.0        15.3        27.2
# 2024-10-17               0.0        15.5        27.2
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-03-07                           0.0  1999      3           66
# 1999-03-08                           0.0  1999      3           67
# 1999-03-09                           0.0  1999      3           68
# 1999-03-10                           0.0  1999      3           69
# 1999-03-11                           0.0  1999      3           70
# ...                                  ...   ...    ...          ...
# 2024-10-13                           0.0  2024     10          287
# 2024-10-14                           0.0  2024     10          288
# 2024-10-15                           0.0  2024     10          289
# 2024-10-16                           0.0  2024     10          290
# 2024-10-17                           0.0  2024     10          291
#
#             Day_of_Week  Month_sin     Month_cos  ...  \
# Time                                              ...
# 1999-03-07            6   1.000000  6.123234e-17  ...
# 1999-03-08            0   1.000000  6.123234e-17  ...
# 1999-03-09            1   1.000000  6.123234e-17  ...
# 1999-03-10            2   1.000000  6.123234e-17  ...
# 1999-03-11            3   1.000000  6.123234e-17  ...
# ...                 ...        ...           ...  ...
# 2024-10-13            6  -0.866025  5.000000e-01  ...
# 2024-10-14            0  -0.866025  5.000000e-01  ...
# 2024-10-15            1  -0.866025  5.000000e-01  ...
# 2024-10-16            2  -0.866025  5.000000e-01  ...
# 2024-10-17            3  -0.866025  5.000000e-01  ...
#
#             Max_Temp_C_rolling_mean_30d  Min_Temp_C_rolling_mean_30d  \
# Time
# 1999-03-07                    26.796667                     6.613333
# 1999-03-08                    27.036667                     6.836667
# 1999-03-09                    27.256667                     7.033333
# 1999-03-10                    27.476667                     7.163333
# 1999-03-11                    27.606667                     7.130000
# ...                                 ...                          ...
# 2024-10-13                    28.726667                    19.016667
# 2024-10-14                    28.693333                    18.940000
# 2024-10-15                    28.663333                    18.813333
# 2024-10-16                    28.636667                    18.693333
# 2024-10-17                    28.563333                    18.546667
#
#             Max_Temp_C_rolling_std_30d  Min_Temp_C_rolling_std_30d  \
# Time
# 1999-03-07                    1.534541                    1.934574
# 1999-03-08                    1.610843                    1.961260
# 1999-03-09                    1.700646                    1.834221
# 1999-03-10                    1.744683                    1.770931
# 1999-03-11                    1.745325                    1.762081
# ...                                ...                         ...
# 2024-10-13                    3.200532                    1.845233
# 2024-10-14                    3.208172                    1.872045
# 2024-10-15                    3.215210                    2.005636
# 2024-10-16                    3.224206                    2.105483
# 2024-10-17                    3.231257                    2.170767
#
#             Precipitation_mm_rolling_sum_7d  Precipitation_mm_rolling_std_7d  \
# Time
# 1999-03-07                              0.0                              0.0
# 1999-03-08                              0.0                              0.0
# 1999-03-09                              0.0                              0.0
# 1999-03-10                              0.0                              0.0
# 1999-03-11                              0.0                              0.0
# ...                                     ...                              ...
# 2024-10-13                              0.0                              0.0
# 2024-10-14                              0.0                              0.0
# 2024-10-15                              0.0                              0.0
# 2024-10-16                              0.0                              0.0
# 2024-10-17                              0.0                              0.0
#
#             Precipitation_mm_rolling_sum_30d  \
# Time
# 1999-03-07                              4.20
# 1999-03-08                              4.20
# 1999-03-09                              4.20
# 1999-03-10                              4.20
# 1999-03-11                              4.20
# ...                                      ...
# 2024-10-13                            332.63
# 2024-10-14                            322.83
# 2024-10-15                            321.33
# 2024-10-16                            298.83
# 2024-10-17                            298.73
#
#             Precipitation_mm_rolling_std_30d  Daily_Temp_Range  \
# Time
# 1999-03-07                          0.766812              19.5
# 1999-03-08                          0.766812              20.7
# 1999-03-09                          0.766812              22.4
# 1999-03-10                          0.766812              22.8
# 1999-03-11                          0.766812              22.4
# ...                                      ...               ...
# 2024-10-13                         43.843094              13.3
# 2024-10-14                         43.889503              10.3
# 2024-10-15                         43.901270              12.5
# 2024-10-16                         43.885114              11.9
# 2024-10-17                         43.885893              11.7
#
#             Daily_Temp_Range_lag_1
# Time
# 1999-03-07                     NaN
# 1999-03-08                    19.5
# 1999-03-09                    20.7
# 1999-03-10                    22.4
# 1999-03-11                    22.8
# ...                            ...
# 2024-10-13                    11.8
# 2024-10-14                    13.3
# 2024-10-15                    10.3
# 2024-10-16                    12.5
# 2024-10-17                    11.9
#
# [9357 rows x 38 columns]

# %%
df_analysis.dropna(inplace=True)

# %%
df_analysis
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-03-08               0.0        10.3        31.0
# 1999-03-09               0.0         8.7        31.1
# 1999-03-10               0.0         8.2        31.0
# 1999-03-11               0.0         7.1        29.5
# 1999-03-12               0.0         6.3        29.1
# ...                      ...         ...         ...
# 2024-10-13               0.0        14.7        28.0
# 2024-10-14               0.0        17.2        27.5
# 2024-10-15               0.0        15.0        27.5
# 2024-10-16               0.0        15.3        27.2
# 2024-10-17               0.0        15.5        27.2
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-03-08                           0.0  1999      3           67
# 1999-03-09                           0.0  1999      3           68
# 1999-03-10                           0.0  1999      3           69
# 1999-03-11                           0.0  1999      3           70
# 1999-03-12                           0.0  1999      3           71
# ...                                  ...   ...    ...          ...
# 2024-10-13                           0.0  2024     10          287
# 2024-10-14                           0.0  2024     10          288
# 2024-10-15                           0.0  2024     10          289
# 2024-10-16                           0.0  2024     10          290
# 2024-10-17                           0.0  2024     10          291
#
#             Day_of_Week  Month_sin     Month_cos  ...  \
# Time                                              ...
# 1999-03-08            0   1.000000  6.123234e-17  ...
# 1999-03-09            1   1.000000  6.123234e-17  ...
# 1999-03-10            2   1.000000  6.123234e-17  ...
# 1999-03-11            3   1.000000  6.123234e-17  ...
# 1999-03-12            4   1.000000  6.123234e-17  ...
# ...                 ...        ...           ...  ...
# 2024-10-13            6  -0.866025  5.000000e-01  ...
# 2024-10-14            0  -0.866025  5.000000e-01  ...
# 2024-10-15            1  -0.866025  5.000000e-01  ...
# 2024-10-16            2  -0.866025  5.000000e-01  ...
# 2024-10-17            3  -0.866025  5.000000e-01  ...
#
#             Max_Temp_C_rolling_mean_30d  Min_Temp_C_rolling_mean_30d  \
# Time
# 1999-03-08                    27.036667                     6.836667
# 1999-03-09                    27.256667                     7.033333
# 1999-03-10                    27.476667                     7.163333
# 1999-03-11                    27.606667                     7.130000
# 1999-03-12                    27.690000                     7.083333
# ...                                 ...                          ...
# 2024-10-13                    28.726667                    19.016667
# 2024-10-14                    28.693333                    18.940000
# 2024-10-15                    28.663333                    18.813333
# 2024-10-16                    28.636667                    18.693333
# 2024-10-17                    28.563333                    18.546667
#
#             Max_Temp_C_rolling_std_30d  Min_Temp_C_rolling_std_30d  \
# Time
# 1999-03-08                    1.610843                    1.961260
# 1999-03-09                    1.700646                    1.834221
# 1999-03-10                    1.744683                    1.770931
# 1999-03-11                    1.745325                    1.762081
# 1999-03-12                    1.755258                    1.765001
# ...                                ...                         ...
# 2024-10-13                    3.200532                    1.845233
# 2024-10-14                    3.208172                    1.872045
# 2024-10-15                    3.215210                    2.005636
# 2024-10-16                    3.224206                    2.105483
# 2024-10-17                    3.231257                    2.170767
#
#             Precipitation_mm_rolling_sum_7d  Precipitation_mm_rolling_std_7d  \
# Time
# 1999-03-08                              0.0                              0.0
# 1999-03-09                              0.0                              0.0
# 1999-03-10                              0.0                              0.0
# 1999-03-11                              0.0                              0.0
# 1999-03-12                              0.0                              0.0
# ...                                     ...                              ...
# 2024-10-13                              0.0                              0.0
# 2024-10-14                              0.0                              0.0
# 2024-10-15                              0.0                              0.0
# 2024-10-16                              0.0                              0.0
# 2024-10-17                              0.0                              0.0
#
#             Precipitation_mm_rolling_sum_30d  \
# Time
# 1999-03-08                              4.20
# 1999-03-09                              4.20
# 1999-03-10                              4.20
# 1999-03-11                              4.20
# 1999-03-12                              4.20
# ...                                      ...
# 2024-10-13                            332.63
# 2024-10-14                            322.83
# 2024-10-15                            321.33
# 2024-10-16                            298.83
# 2024-10-17                            298.73
#
#             Precipitation_mm_rolling_std_30d  Daily_Temp_Range  \
# Time
# 1999-03-08                          0.766812              20.7
# 1999-03-09                          0.766812              22.4
# 1999-03-10                          0.766812              22.8
# 1999-03-11                          0.766812              22.4
# 1999-03-12                          0.766812              22.8
# ...                                      ...               ...
# 2024-10-13                         43.843094              13.3
# 2024-10-14                         43.889503              10.3
# 2024-10-15                         43.901270              12.5
# 2024-10-16                         43.885114              11.9
# 2024-10-17                         43.885893              11.7
#
#             Daily_Temp_Range_lag_1
# Time
# 1999-03-08                    19.5
# 1999-03-09                    20.7
# 1999-03-10                    22.4
# 1999-03-11                    22.8
# 1999-03-12                    22.4
# ...                            ...
# 2024-10-13                    11.8
# 2024-10-14                    13.3
# 2024-10-15                    10.3
# 2024-10-16                    12.5
# 2024-10-17                    11.9
#
# [9356 rows x 38 columns]

# %% [markdown]
# ### Baseline Model Training & Evaluation (Linear Regression):

# %% [markdown]
# ### Implement and Train Gradient Boosting Machine (XGBoost):

# %% [markdown]
# #### Hyperparameter Tuning with TimeSeriesSplit:
# Tuning is crucial to get the best performance from XGBoost. We'll use RandomizedSearchCV as it's more efficient than GridSearchCV for large search spaces, especially when starting out. TimeSeriesSplit ensures our cross-validation folds maintain chronological order, preventing data leakage.

# %% [markdown]
# Slight changes in the code as the target isn't just predicting  tempr after 5 days, but temperature for 1,2,3,4 and 5 days ahead.

# %%
# Drop any previously created 'Target_' columns from the single 5-day ahead setup
df_analysis = df_analysis.drop(columns=[col for col in df_analysis.columns if 'Target_' in str(col)], errors='ignore')

# Create target variables for each horizon (t+1 to t+5) for both Max and Min temperatures
for horizon in range(1, 6): # Horizons from 1 to 5 days ahead
    df_analysis[f'Target_Max_Temp_C_t+{horizon}'] = df_analysis['Max_Temp_C'].shift(-horizon)
    df_analysis[f'Target_Min_Temp_C_t+{horizon}'] = df_analysis['Min_Temp_C'].shift(-horizon)

# Drop rows where any of the new target variables are NaN (these will be at the end of the DataFrame)
# Dropping based on the furthest horizon (t+5) ensures all shorter horizons are also present
df_analysis.dropna(subset=[f'Target_Max_Temp_C_t+5', f'Target_Min_Temp_C_t+5'], inplace=True)

# %%
df_analysis
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-03-08               0.0        10.3        31.0
# 1999-03-09               0.0         8.7        31.1
# 1999-03-10               0.0         8.2        31.0
# 1999-03-11               0.0         7.1        29.5
# 1999-03-12               0.0         6.3        29.1
# ...                      ...         ...         ...
# 2024-10-08               0.0        18.4        28.5
# 2024-10-09               0.0        16.6        29.6
# 2024-10-10               0.0        16.5        29.1
# 2024-10-11               0.0        16.9        28.5
# 2024-10-12               0.0        16.5        28.3
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-03-08                          0.00  1999      3           67
# 1999-03-09                          0.00  1999      3           68
# 1999-03-10                          0.00  1999      3           69
# 1999-03-11                          0.00  1999      3           70
# 1999-03-12                          0.00  1999      3           71
# ...                                  ...   ...    ...          ...
# 2024-10-08                          5.63  2024     10          282
# 2024-10-09                          5.63  2024     10          283
# 2024-10-10                          0.03  2024     10          284
# 2024-10-11                          0.02  2024     10          285
# 2024-10-12                          0.01  2024     10          286
#
#             Day_of_Week  Month_sin     Month_cos  ...  Target_Max_Temp_C_t+1  \
# Time                                              ...
# 1999-03-08            0   1.000000  6.123234e-17  ...                   31.1
# 1999-03-09            1   1.000000  6.123234e-17  ...                   31.0
# 1999-03-10            2   1.000000  6.123234e-17  ...                   29.5
# 1999-03-11            3   1.000000  6.123234e-17  ...                   29.1
# 1999-03-12            4   1.000000  6.123234e-17  ...                   28.1
# ...                 ...        ...           ...  ...                    ...
# 2024-10-08            1  -0.866025  5.000000e-01  ...                   29.6
# 2024-10-09            2  -0.866025  5.000000e-01  ...                   29.1
# 2024-10-10            3  -0.866025  5.000000e-01  ...                   28.5
# 2024-10-11            4  -0.866025  5.000000e-01  ...                   28.3
# 2024-10-12            5  -0.866025  5.000000e-01  ...                   28.0
#
#             Target_Min_Temp_C_t+1  Target_Max_Temp_C_t+2  \
# Time
# 1999-03-08                    8.7                   31.0
# 1999-03-09                    8.2                   29.5
# 1999-03-10                    7.1                   29.1
# 1999-03-11                    6.3                   28.1
# 1999-03-12                    5.5                   28.0
# ...                           ...                    ...
# 2024-10-08                   16.6                   29.1
# 2024-10-09                   16.5                   28.5
# 2024-10-10                   16.9                   28.3
# 2024-10-11                   16.5                   28.0
# 2024-10-12                   14.7                   27.5
#
#             Target_Min_Temp_C_t+2  Target_Max_Temp_C_t+3  \
# Time
# 1999-03-08                    8.2                   29.5
# 1999-03-09                    7.1                   29.1
# 1999-03-10                    6.3                   28.1
# 1999-03-11                    5.5                   28.0
# 1999-03-12                    4.1                   25.0
# ...                           ...                    ...
# 2024-10-08                   16.5                   28.5
# 2024-10-09                   16.9                   28.3
# 2024-10-10                   16.5                   28.0
# 2024-10-11                   14.7                   27.5
# 2024-10-12                   17.2                   27.5
#
#             Target_Min_Temp_C_t+3  Target_Max_Temp_C_t+4  \
# Time
# 1999-03-08                    7.1                   29.1
# 1999-03-09                    6.3                   28.1
# 1999-03-10                    5.5                   28.0
# 1999-03-11                    4.1                   25.0
# 1999-03-12                    6.4                   26.4
# ...                           ...                    ...
# 2024-10-08                   16.9                   28.3
# 2024-10-09                   16.5                   28.0
# 2024-10-10                   14.7                   27.5
# 2024-10-11                   17.2                   27.5
# 2024-10-12                   15.0                   27.2
#
#             Target_Min_Temp_C_t+4  Target_Max_Temp_C_t+5  \
# Time
# 1999-03-08                    6.3                   28.1
# 1999-03-09                    5.5                   28.0
# 1999-03-10                    4.1                   25.0
# 1999-03-11                    6.4                   26.4
# 1999-03-12                    7.5                   29.5
# ...                           ...                    ...
# 2024-10-08                   16.5                   28.0
# 2024-10-09                   14.7                   27.5
# 2024-10-10                   17.2                   27.5
# 2024-10-11                   15.0                   27.2
# 2024-10-12                   15.3                   27.2
#
#             Target_Min_Temp_C_t+5
# Time
# 1999-03-08                    5.5
# 1999-03-09                    4.1
# 1999-03-10                    6.4
# 1999-03-11                    7.5
# 1999-03-12                    7.4
# ...                           ...
# 2024-10-08                   14.7
# 2024-10-09                   17.2
# 2024-10-10                   15.0
# 2024-10-11                   15.3
# 2024-10-12                   15.5
#
# [9351 rows x 48 columns]

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9351 entries, 1999-03-08 to 2024-10-12
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Precipitation_mm                  9351 non-null   float64
#  1   Min_Temp_C                        9351 non-null   float64
#  2   Max_Temp_C                        9351 non-null   float64
#  3   Precipitation_7d_rolling_sum      9351 non-null   float64
#  4   Year                              9351 non-null   int64
#  5   Month                             9351 non-null   int64
#  6   Day_of_Year                       9351 non-null   int64
#  7   Day_of_Week                       9351 non-null   int64
#  8   Month_sin                         9351 non-null   float64
#  9   Month_cos                         9351 non-null   float64
#  10  Day_of_Year_sin                   9351 non-null   float64
#  11  Day_of_Year_cos                   9351 non-null   float64
#  12  Max_Temp_C_lag_1                  9351 non-null   float64
#  13  Min_Temp_C_lag_1                  9351 non-null   float64
#  14  Max_Temp_C_lag_2                  9351 non-null   float64
#  15  Min_Temp_C_lag_2                  9351 non-null   float64
#  16  Max_Temp_C_lag_3                  9351 non-null   float64
#  17  Min_Temp_C_lag_3                  9351 non-null   float64
#  18  Max_Temp_C_lag_7                  9351 non-null   float64
#  19  Min_Temp_C_lag_7                  9351 non-null   float64
#  20  Precipitation_mm_lag_1            9351 non-null   float64
#  21  Precipitation_mm_lag_2            9351 non-null   float64
#  22  Precipitation_mm_lag_3            9351 non-null   float64
#  23  Precipitation_mm_lag_7            9351 non-null   float64
#  24  Max_Temp_C_rolling_mean_7d        9351 non-null   float64
#  25  Min_Temp_C_rolling_mean_7d        9351 non-null   float64
#  26  Max_Temp_C_rolling_std_7d         9351 non-null   float64
#  27  Min_Temp_C_rolling_std_7d         9351 non-null   float64
#  28  Max_Temp_C_rolling_mean_30d       9351 non-null   float64
#  29  Min_Temp_C_rolling_mean_30d       9351 non-null   float64
#  30  Max_Temp_C_rolling_std_30d        9351 non-null   float64
#  31  Min_Temp_C_rolling_std_30d        9351 non-null   float64
#  32  Precipitation_mm_rolling_sum_7d   9351 non-null   float64
#  33  Precipitation_mm_rolling_std_7d   9351 non-null   float64
#  34  Precipitation_mm_rolling_sum_30d  9351 non-null   float64
#  35  Precipitation_mm_rolling_std_30d  9351 non-null   float64
#  36  Daily_Temp_Range                  9351 non-null   float64
#  37  Daily_Temp_Range_lag_1            9351 non-null   float64
#  38  Target_Max_Temp_C_t+1             9351 non-null   float64
#  39  Target_Min_Temp_C_t+1             9351 non-null   float64
#  40  Target_Max_Temp_C_t+2             9351 non-null   float64
#  41  Target_Min_Temp_C_t+2             9351 non-null   float64
#  42  Target_Max_Temp_C_t+3             9351 non-null   float64
#  43  Target_Min_Temp_C_t+3             9351 non-null   float64
#  44  Target_Max_Temp_C_t+4             9351 non-null   float64
#  45  Target_Min_Temp_C_t+4             9351 non-null   float64
#  46  Target_Max_Temp_C_t+5             9351 non-null   float64
#  47  Target_Min_Temp_C_t+5             9351 non-null   float64
# dtypes: float64(44), int64(4)
# memory usage: 3.5+ MB

# %%
# List of all multi-horizon target columns
target_columns = [col for col in df_analysis.columns if 'Target_' in str(col)]

# Identify features (X) and targets (y)
# X includes all non-target, non-original temperature columns
feature_columns = [col for col in df_analysis.columns if col not in ['Max_Temp_C', 'Min_Temp_C'] + target_columns]

X = df_analysis[feature_columns]
y = df_analysis[target_columns] # y is now a DataFrame with 10 target columns.

# %%
df_analysis
# Out:
#             Precipitation_mm  Min_Temp_C  Max_Temp_C  \
# Time
# 1999-03-08               0.0        10.3        31.0
# 1999-03-09               0.0         8.7        31.1
# 1999-03-10               0.0         8.2        31.0
# 1999-03-11               0.0         7.1        29.5
# 1999-03-12               0.0         6.3        29.1
# ...                      ...         ...         ...
# 2024-10-08               0.0        18.4        28.5
# 2024-10-09               0.0        16.6        29.6
# 2024-10-10               0.0        16.5        29.1
# 2024-10-11               0.0        16.9        28.5
# 2024-10-12               0.0        16.5        28.3
#
#             Precipitation_7d_rolling_sum  Year  Month  Day_of_Year  \
# Time
# 1999-03-08                          0.00  1999      3           67
# 1999-03-09                          0.00  1999      3           68
# 1999-03-10                          0.00  1999      3           69
# 1999-03-11                          0.00  1999      3           70
# 1999-03-12                          0.00  1999      3           71
# ...                                  ...   ...    ...          ...
# 2024-10-08                          5.63  2024     10          282
# 2024-10-09                          5.63  2024     10          283
# 2024-10-10                          0.03  2024     10          284
# 2024-10-11                          0.02  2024     10          285
# 2024-10-12                          0.01  2024     10          286
#
#             Day_of_Week  Month_sin     Month_cos  ...  Target_Max_Temp_C_t+1  \
# Time                                              ...
# 1999-03-08            0   1.000000  6.123234e-17  ...                   31.1
# 1999-03-09            1   1.000000  6.123234e-17  ...                   31.0
# 1999-03-10            2   1.000000  6.123234e-17  ...                   29.5
# 1999-03-11            3   1.000000  6.123234e-17  ...                   29.1
# 1999-03-12            4   1.000000  6.123234e-17  ...                   28.1
# ...                 ...        ...           ...  ...                    ...
# 2024-10-08            1  -0.866025  5.000000e-01  ...                   29.6
# 2024-10-09            2  -0.866025  5.000000e-01  ...                   29.1
# 2024-10-10            3  -0.866025  5.000000e-01  ...                   28.5
# 2024-10-11            4  -0.866025  5.000000e-01  ...                   28.3
# 2024-10-12            5  -0.866025  5.000000e-01  ...                   28.0
#
#             Target_Min_Temp_C_t+1  Target_Max_Temp_C_t+2  \
# Time
# 1999-03-08                    8.7                   31.0
# 1999-03-09                    8.2                   29.5
# 1999-03-10                    7.1                   29.1
# 1999-03-11                    6.3                   28.1
# 1999-03-12                    5.5                   28.0
# ...                           ...                    ...
# 2024-10-08                   16.6                   29.1
# 2024-10-09                   16.5                   28.5
# 2024-10-10                   16.9                   28.3
# 2024-10-11                   16.5                   28.0
# 2024-10-12                   14.7                   27.5
#
#             Target_Min_Temp_C_t+2  Target_Max_Temp_C_t+3  \
# Time
# 1999-03-08                    8.2                   29.5
# 1999-03-09                    7.1                   29.1
# 1999-03-10                    6.3                   28.1
# 1999-03-11                    5.5                   28.0
# 1999-03-12                    4.1                   25.0
# ...                           ...                    ...
# 2024-10-08                   16.5                   28.5
# 2024-10-09                   16.9                   28.3
# 2024-10-10                   16.5                   28.0
# 2024-10-11                   14.7                   27.5
# 2024-10-12                   17.2                   27.5
#
#             Target_Min_Temp_C_t+3  Target_Max_Temp_C_t+4  \
# Time
# 1999-03-08                    7.1                   29.1
# 1999-03-09                    6.3                   28.1
# 1999-03-10                    5.5                   28.0
# 1999-03-11                    4.1                   25.0
# 1999-03-12                    6.4                   26.4
# ...                           ...                    ...
# 2024-10-08                   16.9                   28.3
# 2024-10-09                   16.5                   28.0
# 2024-10-10                   14.7                   27.5
# 2024-10-11                   17.2                   27.5
# 2024-10-12                   15.0                   27.2
#
#             Target_Min_Temp_C_t+4  Target_Max_Temp_C_t+5  \
# Time
# 1999-03-08                    6.3                   28.1
# 1999-03-09                    5.5                   28.0
# 1999-03-10                    4.1                   25.0
# 1999-03-11                    6.4                   26.4
# 1999-03-12                    7.5                   29.5
# ...                           ...                    ...
# 2024-10-08                   16.5                   28.0
# 2024-10-09                   14.7                   27.5
# 2024-10-10                   17.2                   27.5
# 2024-10-11                   15.0                   27.2
# 2024-10-12                   15.3                   27.2
#
#             Target_Min_Temp_C_t+5
# Time
# 1999-03-08                    5.5
# 1999-03-09                    4.1
# 1999-03-10                    6.4
# 1999-03-11                    7.5
# 1999-03-12                    7.4
# ...                           ...
# 2024-10-08                   14.7
# 2024-10-09                   17.2
# 2024-10-10                   15.0
# 2024-10-11                   15.3
# 2024-10-12                   15.5
#
# [9351 rows x 48 columns]

# %%
df_analysis.isnull().sum()
# Out:
# Precipitation_mm                    0
# Min_Temp_C                          0
# Max_Temp_C                          0
# Precipitation_7d_rolling_sum        0
# Year                                0
# Month                               0
# Day_of_Year                         0
# Day_of_Week                         0
# Month_sin                           0
# Month_cos                           0
# Day_of_Year_sin                     0
# Day_of_Year_cos                     0
# Max_Temp_C_lag_1                    0
# Min_Temp_C_lag_1                    0
# Max_Temp_C_lag_2                    0
# Min_Temp_C_lag_2                    0
# Max_Temp_C_lag_3                    0
# Min_Temp_C_lag_3                    0
# Max_Temp_C_lag_7                    0
# Min_Temp_C_lag_7                    0
# Precipitation_mm_lag_1              0
# Precipitation_mm_lag_2              0
# Precipitation_mm_lag_3              0
# Precipitation_mm_lag_7              0
# Max_Temp_C_rolling_mean_7d          0
# Min_Temp_C_rolling_mean_7d          0
# Max_Temp_C_rolling_std_7d           0
# Min_Temp_C_rolling_std_7d           0
# Max_Temp_C_rolling_mean_30d         0
# Min_Temp_C_rolling_mean_30d         0
# Max_Temp_C_rolling_std_30d          0
# Min_Temp_C_rolling_std_30d          0
# Precipitation_mm_rolling_sum_7d     0
# Precipitation_mm_rolling_std_7d     0
# Precipitation_mm_rolling_sum_30d    0
# Precipitation_mm_rolling_std_30d    0
# Daily_Temp_Range                    0
# Daily_Temp_Range_lag_1              0
# Target_Max_Temp_C_t+1               0
# Target_Min_Temp_C_t+1               0
# Target_Max_Temp_C_t+2               0
# Target_Min_Temp_C_t+2               0
# Target_Max_Temp_C_t+3               0
# Target_Min_Temp_C_t+3               0
# Target_Max_Temp_C_t+4               0
# Target_Min_Temp_C_t+4               0
# Target_Max_Temp_C_t+5               0
# Target_Min_Temp_C_t+5               0
# dtype: int64

# %%
# Determine the split point (e.g., 80% of the data)
split_index = int(len(df_analysis) * 0.8)

X_train = X.iloc[:split_index]
X_test = X.iloc[split_index:]
y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
print(f"Train data ends on: {X_train.index.max()}")
print(f"Test data starts on: {X_test.index.min()}")
# Out:
# X_train shape: (7480, 36), y_train shape: (7480, 10)
# X_test shape: (1871, 36), y_test shape: (1871, 10)
# Train data ends on: 2019-08-29
# Test data starts on: 2019-08-30

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

print("\n--- Training Baseline Model (Linear Regression) for Multi-Horizon Forecast ---")
baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)
y_pred_baseline = baseline_model.predict(X_test)

print("\nBaseline Model (Linear Regression) Performance:")
for i in range(5): # Iterate through horizons 0 (t+1) to 4 (t+5)
    horizon = i + 1
    # Max Temp for current horizon
    mae_max = mean_absolute_error(y_test[f'Target_Max_Temp_C_t+{horizon}'], y_pred_baseline[:, i*2])
    rmse_max = np.sqrt(mean_squared_error(y_test[f'Target_Max_Temp_C_t+{horizon}'], y_pred_baseline[:, i*2]))
    # Min Temp for current horizon
    mae_min = mean_absolute_error(y_test[f'Target_Min_Temp_C_t+{horizon}'], y_pred_baseline[:, i*2+1])
    rmse_min = np.sqrt(mean_squared_error(y_test[f'Target_Min_Temp_C_t+{horizon}'], y_pred_baseline[:, i*2+1]))

    print(f"Horizon t+{horizon}:")
    print(f"  Max Temp: MAE = {mae_max:.2f} °C, RMSE = {rmse_max:.2f} °C")
    print(f"  Min Temp: MAE = {mae_min:.2f} °C, RMSE = {rmse_min:.2f} °C")
# Out:
# --- Training Baseline Model (Linear Regression) for Multi-Horizon Forecast ---
#
# Baseline Model (Linear Regression) Performance:
# Horizon t+1:
#   Max Temp: MAE = 1.35 °C, RMSE = 1.93 °C
#   Min Temp: MAE = 0.96 °C, RMSE = 1.27 °C
# Horizon t+2:
#   Max Temp: MAE = 1.56 °C, RMSE = 2.18 °C
#   Min Temp: MAE = 1.07 °C, RMSE = 1.40 °C
# Horizon t+3:
#   Max Temp: MAE = 1.65 °C, RMSE = 2.29 °C
#   Min Temp: MAE = 1.13 °C, RMSE = 1.48 °C
# Horizon t+4:
#   Max Temp: MAE = 1.71 °C, RMSE = 2.35 °C
#   Min Temp: MAE = 1.17 °C, RMSE = 1.54 °C
# Horizon t+5:
#   Max Temp: MAE = 1.74 °C, RMSE = 2.37 °C
#   Min Temp: MAE = 1.20 °C, RMSE = 1.57 °C

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.model_selection import train_test_split # To split our data

print("\n--- Starting Hyperparameter Tuning for XGBoost (Multi-Horizon) ---")

# Define a custom scorer that averages MAE across all targets, or focuses on the most critical one.
# For now, let's aim to optimize for the MAE of Max_Temp at horizon t+1, as it's the closest and most visible.
# If you want to average across all 10 targets during tuning, it becomes more complex and can be discussed.
# For simplicity, optimize for the *first* target which is Target_Max_Temp_C_t+1 (index 0 in y_train)

# We need a custom scorer for RandomizedSearchCV for multi-output regression.
# XGBoost can output multiple targets. make_scorer needs a function that takes y_true, y_pred.
# And it needs to return a single score (usually for the primary target of interest).

# Custom scorer for RandomizedSearchCV to optimize for Max_Temp at t+1 (the first output column)
# The scoring function for RandomizedSearchCV should accept (estimator, X, y_true)

def custom_mae_scorer(estimator, X, y_true):
    y_pred = estimator.predict(X)
    # Assuming y_pred[:,0] is Target_Max_Temp_C_t+1 prediction
    return -mean_absolute_error(y_true.iloc[:, 0], y_pred[:, 0]) # Return negative MAE for maximization

# Prepare the estimator
xgb_tuned_estimator = xgb.XGBRegressor(objective='reg:squarederror',
                                       random_state=42,
                                       n_jobs=-1)

param_dist = {
    'n_estimators': [500, 1000, 1500], # Increased upper bound
    'learning_rate': [0.01, 0.05, 0.1, 0.005, 0.2], # Wider range
    'max_depth': [3, 5, 7, 9, 11, 13], # Significantly wider range
    'subsample': [0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'gamma': [0, 0.05, 0.1, 0.2],
    'min_child_weight': [1, 5, 10]
}

tscv = TimeSeriesSplit(n_splits=5)

random_search = RandomizedSearchCV(estimator=xgb_tuned_estimator,
                                   param_distributions=param_dist,
                                   n_iter=50, # Increased iterations for broader search
                                   scoring=custom_mae_scorer, # Use our custom scorer
                                   cv=tscv,
                                   verbose=2, # Increased verbosity to see more output
                                   random_state=42,
                                   return_train_score=True)

# Fit the random search. Use early stopping inside the fit for individual models in the search.
# Note: `RandomizedSearchCV` itself doesn't directly support `eval_set` for early stopping during `fit`.
# To use early stopping effectively with `RandomizedSearchCV`, it's generally done in a custom cross-validation loop
# or by wrapping the model in a way that passes `eval_set`.
# For simplicity in this sprint, let's keep the `eval_set` for the *final* best model fit, not within the RandomizedSearchCV itself,
# as that adds significant complexity. `n_estimators` in param_dist can act as the 'upper bound' if chosen wisely.

# If RandomizedSearchCV takes too long, reduce n_iter or param_dist ranges.
random_search.fit(X_train, y_train)

print(f"\nBest parameters from RandomizedSearchCV: {random_search.best_params_}")
print(f"Best cross-validation MAE (for Target_Max_Temp_C_t+1): {-random_search.best_score_:.2f} °C")

# Get the best estimator found
best_xgb_model = random_search.best_estimator_
# Out:
# --- Starting Hyperparameter Tuning for XGBoost (Multi-Horizon) ---
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0; total time=   5.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0; total time=   6.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0; total time=   8.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0; total time=   8.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=1500, subsample=0.7; total time= 1.7min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=1500, subsample=0.7; total time= 2.6min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=1500, subsample=0.7; total time= 3.3min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=1500, subsample=0.7; total time= 3.9min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=1500, subsample=0.7; total time= 4.6min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.9; total time=  30.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.9; total time=  43.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.9; total time=  59.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.9; total time= 1.5min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  25.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  31.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  38.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  42.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  45.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  15.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  24.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  32.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  41.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=0.7; total time=  40.6s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   7.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   6.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   8.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=10, n_estimators=1500, subsample=0.9; total time=  53.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=10, n_estimators=1500, subsample=0.9; total time= 1.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=10, n_estimators=1500, subsample=0.9; total time= 1.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=10, n_estimators=1500, subsample=0.9; total time= 1.4min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=10, n_estimators=1500, subsample=0.9; total time= 1.5min
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.05, max_depth=11, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  24.0s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.05, max_depth=11, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  33.4s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.05, max_depth=11, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  44.8s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.05, max_depth=11, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  54.9s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.05, max_depth=11, min_child_weight=5, n_estimators=1500, subsample=1.0; total time= 1.1min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  11.7s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  15.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  20.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  24.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  29.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0; total time=  12.9s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0; total time=  15.5s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 2.6min
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 3.1min
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 3.4min
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=9, min_child_weight=1, n_estimators=1000, subsample=0.9; total time= 3.9min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=11, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  19.2s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=11, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  27.3s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=11, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  35.4s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=11, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  42.6s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=11, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  51.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8; total time=  37.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8; total time=  59.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8; total time= 1.6min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.005, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8; total time= 1.4min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=1500, subsample=0.8; total time=  25.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=1500, subsample=0.8; total time=  37.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=1500, subsample=0.8; total time=  46.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=1500, subsample=0.8; total time=  51.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=1500, subsample=0.8; total time=  55.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  21.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  34.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  47.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, subsample=1.0; total time= 1.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1000, subsample=1.0; total time= 1.2min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.005, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=1.0; total time= 1.7min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.005, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=1.0; total time= 2.0min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.005, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=1.0; total time= 2.1min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.005, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.005, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=1.0; total time= 2.6min
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  18.0s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  19.8s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  28.3s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.7; total time=  27.7s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=500, subsample=0.7; total time=   8.9s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=500, subsample=0.7; total time=  15.3s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=500, subsample=0.7; total time=  19.8s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=500, subsample=0.7; total time=  24.2s
# [CV] END colsample_bytree=0.8, gamma=0.05, learning_rate=0.2, max_depth=9, min_child_weight=10, n_estimators=500, subsample=0.7; total time=  32.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.9; total time=   7.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.9; total time=   7.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.9; total time=   7.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.9; total time=   8.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.9; total time=  11.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=1.0; total time=  17.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=1.0; total time=  23.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=1.0; total time=  30.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=1.0; total time=  37.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=1.0; total time=  44.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1500, subsample=0.8; total time= 6.8min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=10.1min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=14.2min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=12.3min
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=13.3min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.8; total time= 3.0min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.8; total time= 4.2min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.8; total time= 5.5min
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.8; total time= 6.2min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.005, max_depth=11, min_child_weight=10, n_estimators=500, subsample=1.0; total time=  41.0s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.005, max_depth=11, min_child_weight=10, n_estimators=500, subsample=1.0; total time= 1.4min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.005, max_depth=11, min_child_weight=10, n_estimators=500, subsample=1.0; total time= 1.9min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.005, max_depth=11, min_child_weight=10, n_estimators=500, subsample=1.0; total time= 2.3min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.005, max_depth=11, min_child_weight=10, n_estimators=500, subsample=1.0; total time= 2.8min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 2.8min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 4.7min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 7.6min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 9.1min
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.01, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=10.0min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  18.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  26.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  41.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  47.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=11, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  57.8s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.7; total time=  29.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.7; total time=  43.9s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.7; total time= 1.0min
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.7; total time= 1.2min
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.7; total time= 1.4min
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   8.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   9.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  10.7s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  11.7s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  12.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 2.6min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 3.9min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 4.0min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 4.5min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=13, min_child_weight=5, n_estimators=1000, subsample=0.9; total time= 5.2min
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.9; total time=  13.6s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.9; total time=  17.7s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.9; total time=  15.0s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.9; total time=  17.9s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.9; total time=  32.0s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  10.4s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=   9.7s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  13.5s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  16.5s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=  19.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=0.7; total time= 4.3min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=0.7; total time= 6.8min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=0.7; total time=10.9min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=0.7; total time=11.0min
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=11, min_child_weight=1, n_estimators=1500, subsample=0.7; total time=12.5min
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.005, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 4.4min
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.005, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 8.1min
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.005, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time= 9.6min
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.005, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=10.5min
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.005, max_depth=13, min_child_weight=1, n_estimators=1000, subsample=1.0; total time=11.3min
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  16.8s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  25.1s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  34.0s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  42.8s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=10, n_estimators=1000, subsample=0.8; total time=  54.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  14.7s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  19.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  21.6s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  23.3s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  17.1s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  26.5s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  36.1s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  45.8s
# [CV] END colsample_bytree=0.9, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=1500, subsample=0.8; total time=  55.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   6.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   7.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   7.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   8.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  17.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  19.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  21.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  22.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  24.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  12.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  12.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  13.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  14.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  15.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=   7.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=   9.7s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  14.5s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=1500, subsample=1.0; total time=  17.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  16.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  25.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  35.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  45.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.9; total time=  54.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  10.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  12.0s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  13.2s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  14.2s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.9; total time=  15.6s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=1500, subsample=0.8; total time=  19.6s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=1500, subsample=0.8; total time=  29.4s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=1500, subsample=0.8; total time=  40.5s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=1500, subsample=0.8; total time=  49.3s
# [CV] END colsample_bytree=1.0, gamma=0.05, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=1500, subsample=0.8; total time=  54.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  12.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  16.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  20.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  25.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=5, n_estimators=1500, subsample=0.7; total time=  30.2s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=  11.7s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=  19.1s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=  28.6s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=  33.2s
# [CV] END colsample_bytree=0.7, gamma=0.05, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=  38.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  24.7s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  28.4s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  30.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  32.0s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.005, max_depth=5, min_child_weight=5, n_estimators=1000, subsample=1.0; total time=  34.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.8; total time=  23.9s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.8; total time=  34.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.8; total time=  45.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.8; total time=  56.9s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=11, min_child_weight=5, n_estimators=500, subsample=0.8; total time= 1.2min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.8; total time=  35.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.8; total time=  58.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.8; total time= 1.3min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.8; total time= 1.7min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.005, max_depth=13, min_child_weight=10, n_estimators=500, subsample=0.8; total time= 1.9min
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000, subsample=0.8; total time=  16.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8; total time=   8.5s
#
# Best parameters from RandomizedSearchCV: {'subsample': 0.8, 'n_estimators': 1000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0.1, 'colsample_bytree': 0.9}
# Best cross-validation MAE (for Target_Max_Temp_C_t+1): 1.36 °C
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 73
#      67 # Now, fit the best model on the full X_train for final evaluation with early stopping
#      68 # Create a small validation set from your training data for early stopping
#      69 X_train_fit, X_val_fit, y_train_fit, y_val_fit = train_test_split(
#      70     X_train, y_train, test_size=0.15, random_state=42, shuffle=False # Keep shuffle=False for time-series
#      71 )
# ---> 73 best_xgb_model.fit(X_train_fit, y_train_fit,
#      74                    eval_set=[(X_val_fit, y_val_fit)],
#      75                    eval_metric='mae', # Monitor Mean Absolute Error on the validation set for ALL targets
#      76                    early_stopping_rounds=100, # Increased rounds
#      77                    verbose=True) # Set to True to see progress during fitting
#
# File ~\anaconda3\envs\py311-env\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# TypeError: XGBModel.fit() got an unexpected keyword argument 'eval_metric'
